# %%
import pandas as pd

# %%
# Help Link:
# https://towardsdatascience.com/how-to-master-pandas-8514f33f00f6

# data = pd.read_csv('happiness_with_continent.csv')
data = pd.read_csv('https://raw.githubusercontent.com/FBosler/you-datascientist/master/happiness_with_continent.csv')

# pd.read_clipboard

# This one I use rarely, but certainly works for smaller tables. 
# Just mark and copy (ctrl+c) a table from google sheets for example and run pd.read_clipboard().

# %%
# Noteworthy parameters for the read_csv based functions (and read_clipboard).

# sep: 
# - separator for the columns (defaults to, but could also be tab)

# header: 
# - defaults to 'infer' (i.e., Pandas guesses as to what your header is),
# alternatives are an integer or a list of integers
# E.g., you could do header=3 and the dataframe would start with row 4
# If data has no header, use:
# header=None

# names:
# - names of the columns.
# If you want to use this parameter to override whatever column names Pandas had inferred,
# Should specify header=0, (or whatever line your columns names are in),
# If you do not do this, you will have your names as the column names and then the original
# column names in the first row.

# %%
# 1) Inspecting - First, last, random rows
# Preview first 5 rows:
data.head(5)
# Last 5 rows:
data.tail(5)
# 5 random rows:
data.sample(5)

pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 8)

# %%
# 2) Inspecting - shape, columns, index, info, describe
# 1704 rows, 27 columns:
data.shape
# Returns dimensions of the DataFrame.
# Ex) Out: (1704, 27)
# Out:
# (1704, 27)

# %%
data.columns
# Out:
# Index(['Country name', 'Year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect',
#        'Confidence in national government', 'Democratic Quality',
#        'Delivery Quality', 'Standard deviation of ladder by country-year',
#        'Standard deviation/Mean of ladder by country-year',
#        'GINI index (World Bank estimate)',
#        'GINI index (World Bank estimate), average 2000-16',
#        'gini of household income reported in Gallup, by wp5-year',
#        'Most people can be trusted, Gallup',
#        'Most people can be trusted, WVS round 1981-1984',
#        'Most people can be trusted, WVS round 1989-1993',
#        'Most people can be trusted, WVS round 1994-1998',
#        'Most people can be trusted, WVS round 1999-2004',
#        'Most people can be trusted, WVS round 2005-2009',
#        'Most people can be trusted, WVS round 2010-2014', 'Continent'],
#       dtype='object')

# %%
data.sort_values(by='Year')
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 130       Belgium  2005     7.262290           10.591697        0.934875
# 397       Denmark  2005     8.018934           10.704770        0.972372
# 844       Lebanon  2005     5.491245            9.414857        0.796278
# 624       Hungary  2005     5.193933           10.019172        0.929628
# ...           ...   ...          ...                 ...             ...
# 568        Greece  2018     5.409289           10.132058        0.793501
# 1217  Philippines  2018     5.869173            8.985703        0.845803
# 518        Gambia  2018     4.922099            7.376554        0.684800
# 1703     Zimbabwe  2018     3.616480            7.553395        0.775388
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 130                          69.900002                      0.923843
# 397                          69.599998                      0.971135
# 844                          64.599998                      0.703206
# 624                          64.599998                      0.696874
# ...                                ...                           ...
# 568                          72.400002                      0.564456
# 1217                         61.900002                      0.917808
# 518                          55.000000                      0.718729
# 1703                         55.599998                      0.762675
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect  \
# 130          NaN                   0.597554         0.796279         0.260380
# 397          NaN                   0.236522         0.859549         0.153672
# 844          NaN                   0.945177         0.584244         0.292150
# 624          NaN                   0.902811         0.675444         0.290327
# ...          ...                        ...              ...              ...
# 568    -0.336385                   0.860302         0.665699         0.255007
# 1217   -0.113129                   0.726483         0.772846         0.393481
# 518          NaN                   0.691070         0.804012         0.379208
# 1703   -0.038384                   0.844209         0.710119         0.211726
#
#       Confidence in national government  Democratic Quality  Delivery Quality  \
# 130                            0.551705            1.108286          1.409674
# 397                            0.668683            1.407144          2.001794
# 844                                 NaN           -0.641525         -0.303633
# 624                            0.360526            1.089105          0.839862
# ...                                 ...                 ...               ...
# 568                            0.157049                 NaN               NaN
# 1217                           0.802007                 NaN               NaN
# 518                            0.757543                 NaN               NaN
# 1703                           0.550508                 NaN               NaN
#
#       Standard deviation of ladder by country-year  \
# 130                                       1.499964
# 397                                       1.340592
# 844                                       2.267514
# 624                                       2.069027
# ...                                            ...
# 568                                       2.079771
# 1217                                      2.700258
# 518                                       3.158858
# 1703                                      2.498696
#
#       Standard deviation/Mean of ladder by country-year  \
# 130                                            0.206541
# 397                                            0.167178
# 844                                            0.412933
# 624                                            0.398355
# ...                                                 ...
# 568                                            0.384481
# 1217                                           0.460075
# 518                                            0.641770
# 1703                                           0.690919
#
#       GINI index (World Bank estimate)  \
# 130                              0.293
# 397                              0.252
# 844                                NaN
# 624                              0.347
# ...                                ...
# 568                                NaN
# 1217                               NaN
# 518                                NaN
# 1703                               NaN
#
#       GINI index (World Bank estimate), average 2000-16  \
# 130                                            0.284308
# 397                                            0.267000
# 844                                            0.318000
# 624                                            0.297917
# ...                                                 ...
# 568                                            0.346385
# 1217                                                NaN
# 518                                            0.422667
# 1703                                           0.432000
#
#       gini of household income reported in Gallup, by wp5-year  \
# 130                                                 NaN
# 397                                                 NaN
# 844                                                 NaN
# 624                                                 NaN
# ...                                                 ...
# 568                                            0.315494
# 1217                                           0.474452
# 518                                            0.592391
# 1703                                           0.541772
#
#       Most people can be trusted, Gallup  \
# 130                                  NaN
# 397                                  NaN
# 844                                  NaN
# 624                                  NaN
# ...                                  ...
# 568                                  NaN
# 1217                                 NaN
# 518                                  NaN
# 1703                                 NaN
#
#       Most people can be trusted, WVS round 1981-1984  \
# 130                                               NaN
# 397                                               NaN
# 844                                               NaN
# 624                                          0.331434
# ...                                               ...
# 568                                               NaN
# 1217                                              NaN
# 518                                               NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1989-1993  \
# 130                                               NaN
# 397                                               NaN
# 844                                               NaN
# 624                                               NaN
# ...                                               ...
# 568                                               NaN
# 1217                                              NaN
# 518                                               NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1994-1998  \
# 130                                               NaN
# 397                                               NaN
# 844                                               NaN
# 624                                          0.224615
# ...                                               ...
# 568                                               NaN
# 1217                                         0.055000
# 518                                               NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1999-2004  \
# 130                                               NaN
# 397                                               NaN
# 844                                               NaN
# 624                                               NaN
# ...                                               ...
# 568                                               NaN
# 1217                                         0.082936
# 518                                               NaN
# 1703                                         0.116683
#
#       Most people can be trusted, WVS round 2005-2009  \
# 130                                               NaN
# 397                                               NaN
# 844                                               NaN
# 624                                          0.288842
# ...                                               ...
# 568                                               NaN
# 1217                                              NaN
# 518                                               NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 2010-2014 Continent
# 130                                               NaN    Europe
# 397                                               NaN    Europe
# 844                                          0.098333      Asia
# 624                                               NaN    Europe
# ...                                               ...       ...
# 568                                               NaN    Europe
# 1217                                         0.031518      Asia
# 518                                               NaN    Africa
# 1703                                         0.082942    Africa
#
# [1704 rows x 27 columns]

# %%
data.sort_values(by=['Year','Country name'])
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 59      Australia  2005     7.340688           10.569470        0.967892
# 130       Belgium  2005     7.262290           10.591697        0.934875
# 192        Brazil  2005     6.636771            9.417240        0.882923
# 258        Canada  2005     7.418048           10.608347        0.961552
# ...           ...   ...          ...                 ...             ...
# 1667      Vietnam  2018     5.295547            8.783416        0.831945
# 1678        Yemen  2018     3.057514                 NaN        0.789422
# 1690       Zambia  2018     4.041488            8.223958        0.717720
# 1703     Zimbabwe  2018     3.616480            7.553395        0.775388
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 59                           71.400002                      0.934973
# 130                          69.900002                      0.923843
# 192                          63.299999                      0.882186
# 258                          71.300003                      0.957306
# ...                                ...                           ...
# 1667                         67.900002                      0.909260
# 1678                         56.700001                      0.552726
# 1690                         55.299999                      0.790626
# 1703                         55.599998                      0.762675
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect  \
# 59           NaN                   0.390416         0.842648         0.238012
# 130          NaN                   0.597554         0.796279         0.260380
# 192          NaN                   0.744994         0.818337         0.301780
# 258     0.244575                   0.502681         0.838544         0.233278
# ...          ...                        ...              ...              ...
# 1667   -0.039124                   0.808423         0.692222         0.191061
# 1678         NaN                   0.792587         0.461114         0.314870
# 1690    0.036644                   0.810731         0.702698         0.350963
# 1703   -0.038384                   0.844209         0.710119         0.211726
#
#       Confidence in national government  Democratic Quality  Delivery Quality  \
# 59                             0.532063            1.200284          1.757166
# 130                            0.551705            1.108286          1.409674
# 192                            0.340625            0.096596         -0.156601
# 258                            0.442818            1.168249          1.748819
# ...                                 ...                 ...               ...
# 1667                                NaN                 NaN               NaN
# 1678                           0.308151                 NaN               NaN
# 1690                           0.606715                 NaN               NaN
# 1703                           0.550508                 NaN               NaN
#
#       Standard deviation of ladder by country-year  \
# 59                                        1.527053
# 130                                       1.499964
# 192                                       2.436181
# 258                                       1.636804
# ...                                            ...
# 1667                                      1.676448
# 1678                                      2.402008
# 1690                                      2.783419
# 1703                                      2.498696
#
#       Standard deviation/Mean of ladder by country-year  \
# 59                                             0.208026
# 130                                            0.206541
# 192                                            0.367073
# 258                                            0.220652
# ...                                                 ...
# 1667                                           0.316577
# 1678                                           0.785608
# 1690                                           0.688711
# 1703                                           0.690919
#
#       GINI index (World Bank estimate)  \
# 59                                 NaN
# 130                              0.293
# 192                              0.563
# 258                                NaN
# ...                                ...
# 1667                               NaN
# 1678                               NaN
# 1690                               NaN
# 1703                               NaN
#
#       GINI index (World Bank estimate), average 2000-16  \
# 59                                             0.342750
# 130                                            0.284308
# 192                                            0.547286
# 258                                            0.336800
# ...                                                 ...
# 1667                                           0.362750
# 1678                                           0.357000
# 1690                                           0.527400
# 1703                                           0.432000
#
#       gini of household income reported in Gallup, by wp5-year  \
# 59                                                  NaN
# 130                                                 NaN
# 192                                                 NaN
# 258                                                 NaN
# ...                                                 ...
# 1667                                           0.415666
# 1678                                           0.448597
# 1690                                           0.619443
# 1703                                           0.541772
#
#       Most people can be trusted, Gallup  \
# 59                                   NaN
# 130                                  NaN
# 192                                  NaN
# 258                                  NaN
# ...                                  ...
# 1667                                 NaN
# 1678                                 NaN
# 1690                                 NaN
# 1703                                 NaN
#
#       Most people can be trusted, WVS round 1981-1984  \
# 59                                           0.478149
# 130                                               NaN
# 192                                               NaN
# 258                                               NaN
# ...                                               ...
# 1667                                              NaN
# 1678                                              NaN
# 1690                                              NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1989-1993  \
# 59                                                NaN
# 130                                               NaN
# 192                                           0.06602
# 258                                               NaN
# ...                                               ...
# 1667                                              NaN
# 1678                                              NaN
# 1690                                              NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1994-1998  \
# 59                                           0.394492
# 130                                               NaN
# 192                                               NaN
# 258                                               NaN
# ...                                               ...
# 1667                                              NaN
# 1678                                              NaN
# 1690                                              NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1999-2004  \
# 59                                                NaN
# 130                                               NaN
# 192                                               NaN
# 258                                          0.385469
# ...                                               ...
# 1667                                         0.387000
# 1678                                              NaN
# 1690                                              NaN
# 1703                                         0.116683
#
#       Most people can be trusted, WVS round 2005-2009  \
# 59                                           0.461379
# 130                                               NaN
# 192                                          0.093811
# 258                                          0.418500
# ...                                               ...
# 1667                                         0.510054
# 1678                                              NaN
# 1690                                         0.110429
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 2010-2014      Continent
# 59                                           0.518140        Oceania
# 130                                               NaN         Europe
# 192                                          0.070638  South America
# 258                                               NaN  North America
# ...                                               ...            ...
# 1667                                              NaN           Asia
# 1678                                         0.385000           Asia
# 1690                                              NaN         Africa
# 1703                                         0.082942         Africa
#
# [1704 rows x 27 columns]

# %%
data.sort_values(by=['Country name','Year'])
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.168690        0.450662
# 1     Afghanistan  2009     4.401778            7.333790        0.552308
# 2     Afghanistan  2010     4.758381            7.386629        0.539075
# 3     Afghanistan  2011     3.831719            7.415019        0.521104
# ...           ...   ...          ...                 ...             ...
# 1700     Zimbabwe  2015     3.703191            7.556052        0.735800
# 1701     Zimbabwe  2016     3.735400            7.538829        0.768425
# 1702     Zimbabwe  2017     3.638300            7.549491        0.754147
# 1703     Zimbabwe  2018     3.616480            7.553395        0.775388
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 0                            50.799999                      0.718114
# 1                            51.200001                      0.678896
# 2                            51.599998                      0.600127
# 3                            51.919998                      0.495901
# ...                                ...                           ...
# 1700                         53.799999                      0.667193
# 1701                         54.400002                      0.732971
# 1702                         55.000000                      0.752826
# 1703                         55.599998                      0.762675
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect  \
# 0       0.177889                   0.881686         0.517637         0.258195
# 1       0.200178                   0.850035         0.583926         0.237092
# 2       0.134353                   0.706766         0.618265         0.275324
# 3       0.172137                   0.731109         0.611387         0.267175
# ...          ...                        ...              ...              ...
# 1700   -0.097354                   0.810457         0.715079         0.178861
# 1701   -0.068105                   0.723612         0.737636         0.208555
# 1702   -0.069670                   0.751208         0.806428         0.224051
# 1703   -0.038384                   0.844209         0.710119         0.211726
#
#       Confidence in national government  Democratic Quality  Delivery Quality  \
# 0                              0.612072           -1.929690         -1.655084
# 1                              0.611545           -2.044093         -1.635025
# 2                              0.299357           -1.991810         -1.617176
# 3                              0.307386           -1.919018         -1.616221
# ...                                 ...                 ...               ...
# 1700                           0.590012           -0.893078         -1.357514
# 1701                           0.699344           -0.900649         -1.374650
# 1702                           0.682647           -0.988153         -1.350867
# 1703                           0.550508                 NaN               NaN
#
#       Standard deviation of ladder by country-year  \
# 0                                         1.774662
# 1                                         1.722688
# 2                                         1.878622
# 3                                         1.785360
# ...                                            ...
# 1700                                      2.198865
# 1701                                      2.776363
# 1702                                      2.656848
# 1703                                      2.498696
#
#       Standard deviation/Mean of ladder by country-year  \
# 0                                              0.476600
# 1                                              0.391362
# 2                                              0.394803
# 3                                              0.465942
# ...                                                 ...
# 1700                                           0.593776
# 1701                                           0.743257
# 1702                                           0.730244
# 1703                                           0.690919
#
#       GINI index (World Bank estimate)  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# ...                                ...
# 1700                               NaN
# 1701                               NaN
# 1702                               NaN
# 1703                               NaN
#
#       GINI index (World Bank estimate), average 2000-16  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# ...                                                 ...
# 1700                                              0.432
# 1701                                              0.432
# 1702                                              0.432
# 1703                                              0.432
#
#       gini of household income reported in Gallup, by wp5-year  \
# 0                                                   NaN
# 1                                              0.441906
# 2                                              0.327318
# 3                                              0.336764
# ...                                                 ...
# 1700                                           0.655137
# 1701                                           0.596690
# 1702                                           0.581484
# 1703                                           0.541772
#
#       Most people can be trusted, Gallup  \
# 0                                    NaN
# 1                               0.286315
# 2                               0.275833
# 3                                    NaN
# ...                                  ...
# 1700                                 NaN
# 1701                                 NaN
# 1702                                 NaN
# 1703                                 NaN
#
#       Most people can be trusted, WVS round 1981-1984  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# ...                                               ...
# 1700                                              NaN
# 1701                                              NaN
# 1702                                              NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1989-1993  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# ...                                               ...
# 1700                                              NaN
# 1701                                              NaN
# 1702                                              NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1994-1998  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# ...                                               ...
# 1700                                              NaN
# 1701                                              NaN
# 1702                                              NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1999-2004  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# ...                                               ...
# 1700                                         0.116683
# 1701                                         0.116683
# 1702                                         0.116683
# 1703                                         0.116683
#
#       Most people can be trusted, WVS round 2005-2009  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# ...                                               ...
# 1700                                              NaN
# 1701                                              NaN
# 1702                                              NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 2010-2014 Continent
# 0                                                 NaN      Asia
# 1                                                 NaN      Asia
# 2                                                 NaN      Asia
# 3                                                 NaN      Asia
# ...                                               ...       ...
# 1700                                         0.082942    Africa
# 1701                                         0.082942    Africa
# 1702                                         0.082942    Africa
# 1703                                         0.082942    Africa
#
# [1704 rows x 27 columns]

# %%
data.sort_values(by='Year', ascending=True)
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 130       Belgium  2005     7.262290           10.591697        0.934875
# 397       Denmark  2005     8.018934           10.704770        0.972372
# 844       Lebanon  2005     5.491245            9.414857        0.796278
# 624       Hungary  2005     5.193933           10.019172        0.929628
# ...           ...   ...          ...                 ...             ...
# 568        Greece  2018     5.409289           10.132058        0.793501
# 1217  Philippines  2018     5.869173            8.985703        0.845803
# 518        Gambia  2018     4.922099            7.376554        0.684800
# 1703     Zimbabwe  2018     3.616480            7.553395        0.775388
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 130                          69.900002                      0.923843
# 397                          69.599998                      0.971135
# 844                          64.599998                      0.703206
# 624                          64.599998                      0.696874
# ...                                ...                           ...
# 568                          72.400002                      0.564456
# 1217                         61.900002                      0.917808
# 518                          55.000000                      0.718729
# 1703                         55.599998                      0.762675
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect  \
# 130          NaN                   0.597554         0.796279         0.260380
# 397          NaN                   0.236522         0.859549         0.153672
# 844          NaN                   0.945177         0.584244         0.292150
# 624          NaN                   0.902811         0.675444         0.290327
# ...          ...                        ...              ...              ...
# 568    -0.336385                   0.860302         0.665699         0.255007
# 1217   -0.113129                   0.726483         0.772846         0.393481
# 518          NaN                   0.691070         0.804012         0.379208
# 1703   -0.038384                   0.844209         0.710119         0.211726
#
#       Confidence in national government  Democratic Quality  Delivery Quality  \
# 130                            0.551705            1.108286          1.409674
# 397                            0.668683            1.407144          2.001794
# 844                                 NaN           -0.641525         -0.303633
# 624                            0.360526            1.089105          0.839862
# ...                                 ...                 ...               ...
# 568                            0.157049                 NaN               NaN
# 1217                           0.802007                 NaN               NaN
# 518                            0.757543                 NaN               NaN
# 1703                           0.550508                 NaN               NaN
#
#       Standard deviation of ladder by country-year  \
# 130                                       1.499964
# 397                                       1.340592
# 844                                       2.267514
# 624                                       2.069027
# ...                                            ...
# 568                                       2.079771
# 1217                                      2.700258
# 518                                       3.158858
# 1703                                      2.498696
#
#       Standard deviation/Mean of ladder by country-year  \
# 130                                            0.206541
# 397                                            0.167178
# 844                                            0.412933
# 624                                            0.398355
# ...                                                 ...
# 568                                            0.384481
# 1217                                           0.460075
# 518                                            0.641770
# 1703                                           0.690919
#
#       GINI index (World Bank estimate)  \
# 130                              0.293
# 397                              0.252
# 844                                NaN
# 624                              0.347
# ...                                ...
# 568                                NaN
# 1217                               NaN
# 518                                NaN
# 1703                               NaN
#
#       GINI index (World Bank estimate), average 2000-16  \
# 130                                            0.284308
# 397                                            0.267000
# 844                                            0.318000
# 624                                            0.297917
# ...                                                 ...
# 568                                            0.346385
# 1217                                                NaN
# 518                                            0.422667
# 1703                                           0.432000
#
#       gini of household income reported in Gallup, by wp5-year  \
# 130                                                 NaN
# 397                                                 NaN
# 844                                                 NaN
# 624                                                 NaN
# ...                                                 ...
# 568                                            0.315494
# 1217                                           0.474452
# 518                                            0.592391
# 1703                                           0.541772
#
#       Most people can be trusted, Gallup  \
# 130                                  NaN
# 397                                  NaN
# 844                                  NaN
# 624                                  NaN
# ...                                  ...
# 568                                  NaN
# 1217                                 NaN
# 518                                  NaN
# 1703                                 NaN
#
#       Most people can be trusted, WVS round 1981-1984  \
# 130                                               NaN
# 397                                               NaN
# 844                                               NaN
# 624                                          0.331434
# ...                                               ...
# 568                                               NaN
# 1217                                              NaN
# 518                                               NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1989-1993  \
# 130                                               NaN
# 397                                               NaN
# 844                                               NaN
# 624                                               NaN
# ...                                               ...
# 568                                               NaN
# 1217                                              NaN
# 518                                               NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1994-1998  \
# 130                                               NaN
# 397                                               NaN
# 844                                               NaN
# 624                                          0.224615
# ...                                               ...
# 568                                               NaN
# 1217                                         0.055000
# 518                                               NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 1999-2004  \
# 130                                               NaN
# 397                                               NaN
# 844                                               NaN
# 624                                               NaN
# ...                                               ...
# 568                                               NaN
# 1217                                         0.082936
# 518                                               NaN
# 1703                                         0.116683
#
#       Most people can be trusted, WVS round 2005-2009  \
# 130                                               NaN
# 397                                               NaN
# 844                                               NaN
# 624                                          0.288842
# ...                                               ...
# 568                                               NaN
# 1217                                              NaN
# 518                                               NaN
# 1703                                              NaN
#
#       Most people can be trusted, WVS round 2010-2014 Continent
# 130                                               NaN    Europe
# 397                                               NaN    Europe
# 844                                          0.098333      Asia
# 624                                               NaN    Europe
# ...                                               ...       ...
# 568                                               NaN    Europe
# 1217                                         0.031518      Asia
# 518                                               NaN    Africa
# 1703                                         0.082942    Africa
#
# [1704 rows x 27 columns]

# %%
data.sort_values(
  by=['Country name','Year'], 
  ascending=[False,True]
)
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 1691     Zimbabwe  2006     3.826268            7.366704        0.821656
# 1692     Zimbabwe  2007     3.280247            7.313939        0.828113
# 1693     Zimbabwe  2008     3.174264            7.102516        0.843475
# 1694     Zimbabwe  2009     4.055914            7.197595        0.805781
# ...           ...   ...          ...                 ...             ...
# 7     Afghanistan  2015     3.982855            7.500539        0.528597
# 8     Afghanistan  2016     4.220169            7.497038        0.559072
# 9     Afghanistan  2017     2.661718            7.497755        0.490880
# 10    Afghanistan  2018     2.694303            7.494588        0.507516
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 1691                         41.580002                      0.431110
# 1692                         42.860001                      0.455957
# 1693                         44.139999                      0.343556
# 1694                         45.419998                      0.411089
# ...                                ...                           ...
# 7                            53.200001                      0.388928
# 8                            53.000000                      0.522566
# 9                            52.799999                      0.427011
# 10                           52.599998                      0.373536
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect  \
# 1691   -0.056554                   0.904757         0.715229         0.297147
# 1692   -0.061563                   0.946287         0.660861         0.264989
# 1693   -0.068002                   0.963846         0.630983         0.250060
# 1694   -0.055836                   0.930818         0.735503         0.218419
# ...          ...                        ...              ...              ...
# 7       0.089091                   0.880638         0.553553         0.339276
# 8       0.051365                   0.793246         0.564953         0.348332
# 9      -0.112198                   0.954393         0.496349         0.371326
# 10     -0.084888                   0.927606         0.424125         0.404904
#
#       Confidence in national government  Democratic Quality  Delivery Quality  \
# 1691                           0.317073           -1.236102         -1.570760
# 1692                           0.225752           -1.340245         -1.653740
# 1693                           0.181594           -1.381488         -1.701545
# 1694                           0.285287           -1.353181         -1.717821
# ...                                 ...                 ...               ...
# 7                              0.260557           -1.844364         -1.291594
# 8                              0.324990           -1.855426         -1.392713
# 9                              0.261179           -1.886566         -1.437808
# 10                             0.364666                 NaN               NaN
#
#       Standard deviation of ladder by country-year  \
# 1691                                      2.013538
# 1692                                      1.929571
# 1693                                      1.685007
# 1694                                      2.024098
# ...                                            ...
# 7                                         2.160618
# 8                                         1.796219
# 9                                         1.454051
# 10                                        1.408344
#
#       Standard deviation/Mean of ladder by country-year  \
# 1691                                           0.526241
# 1692                                           0.588240
# 1693                                           0.530834
# 1694                                           0.499048
# ...                                                 ...
# 7                                              0.542480
# 8                                              0.425627
# 9                                              0.546283
# 10                                             0.522712
#
#       GINI index (World Bank estimate)  \
# 1691                               NaN
# 1692                               NaN
# 1693                               NaN
# 1694                               NaN
# ...                                ...
# 7                                  NaN
# 8                                  NaN
# 9                                  NaN
# 10                                 NaN
#
#       GINI index (World Bank estimate), average 2000-16  \
# 1691                                              0.432
# 1692                                              0.432
# 1693                                              0.432
# 1694                                              0.432
# ...                                                 ...
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
#
#       gini of household income reported in Gallup, by wp5-year  \
# 1691                                                NaN
# 1692                                                NaN
# 1693                                                NaN
# 1694                                           0.545112
# ...                                                 ...
# 7                                              0.596918
# 8                                              0.418629
# 9                                              0.286599
# 10                                             0.290681
#
#       Most people can be trusted, Gallup  \
# 1691                                 NaN
# 1692                                 NaN
# 1693                                 NaN
# 1694                            0.148151
# ...                                  ...
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
#
#       Most people can be trusted, WVS round 1981-1984  \
# 1691                                              NaN
# 1692                                              NaN
# 1693                                              NaN
# 1694                                              NaN
# ...                                               ...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#       Most people can be trusted, WVS round 1989-1993  \
# 1691                                              NaN
# 1692                                              NaN
# 1693                                              NaN
# 1694                                              NaN
# ...                                               ...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#       Most people can be trusted, WVS round 1994-1998  \
# 1691                                              NaN
# 1692                                              NaN
# 1693                                              NaN
# 1694                                              NaN
# ...                                               ...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#       Most people can be trusted, WVS round 1999-2004  \
# 1691                                         0.116683
# 1692                                         0.116683
# 1693                                         0.116683
# 1694                                         0.116683
# ...                                               ...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#       Most people can be trusted, WVS round 2005-2009  \
# 1691                                              NaN
# 1692                                              NaN
# 1693                                              NaN
# 1694                                              NaN
# ...                                               ...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#       Most people can be trusted, WVS round 2010-2014 Continent
# 1691                                         0.082942    Africa
# 1692                                         0.082942    Africa
# 1693                                         0.082942    Africa
# 1694                                         0.082942    Africa
# ...                                               ...       ...
# 7                                                 NaN      Asia
# 8                                                 NaN      Asia
# 9                                                 NaN      Asia
# 10                                                NaN      Asia
#
# [1704 rows x 27 columns]

# %%
# Filtering - columns
# Selecting one column:

data['Year']
# Out:
# 0       2008
# 1       2009
# 2       2010
# 3       2011
#         ...
# 1700    2015
# 1701    2016
# 1702    2017
# 1703    2018
# Name: Year, Length: 1704, dtype: int64

# %%
# Multiple columns:

data[['Country name','Life Ladder']].sample(5)
# Out:
#      Country name  Life Ladder
# 1186     Paraguay     5.820058
# 324      Colombia     6.387572
# 775    Kazakhstan     5.882351
# 1336    Singapore     7.062365
# 1419    Sri Lanka     4.364694

# %%
# Filtering rows:
# Being able to select specific columns is only halfway there.
# However, selecting rows is just as easy.
# Can select one row or multiple rows by index.

data.iloc
# Allows selecting rows (and optionally columns) 
# By position (i.e., by the number of the row).

# Selecting one row:
# Looks like: data.iloc[row_number (,col_number)],
# Where the part in the parentheses is optional.

# %%
data.iloc[10]
# Out:
# Country name                                       Afghanistan
# Year                                                      2018
# Life Ladder                                             2.6943
# Log GDP per capita                                     7.49459
#                                                       ...
# Most people can be trusted, WVS round 1999-2004            NaN
# Most people can be trusted, WVS round 2005-2009            NaN
# Most people can be trusted, WVS round 2010-2014            NaN
# Continent                                                 Asia
# Name: 10, Length: 27, dtype: object

# %%
data.iloc[10, 5]
# Out:
# 52.599998474121094

# %%
# Selecting multiple rows:

# data.iloc[start_row:end_row (, start_col:end_col)],
# where the part in the parenthese is optional.

# %%
data.iloc[903:907]
# Out:
#     Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 903    Macedonia  2015     4.975590            9.454056        0.766368
# 904    Macedonia  2016     5.345746            9.481959        0.871212
# 905    Macedonia  2017     5.233867            9.481223        0.799955
# 906    Macedonia  2018     5.239835            9.503044        0.848915
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# 903                         66.900002                      0.660319
# 904                         67.099998                      0.706179
# 905                         67.300003                      0.752107
# 906                         67.500000                      0.744801
#
#      Generosity  Perceptions of corruption  Positive affect  Negative affect  \
# 903   -0.046411                   0.824179         0.619699         0.299022
# 904    0.079842                   0.869719         0.638737         0.292295
# 905   -0.057992                   0.855697         0.502460         0.299391
# 906   -0.040291                   0.909934         0.590138         0.298353
#
#      Confidence in national government  Democratic Quality  Delivery Quality  \
# 903                           0.367435           -0.234458          0.026333
# 904                           0.256954           -0.293647         -0.005984
# 905                           0.442916           -0.194677          0.024050
# 906                           0.396142                 NaN               NaN
#
#      Standard deviation of ladder by country-year  \
# 903                                      2.260499
# 904                                      2.175041
# 905                                      2.111887
# 906                                      2.150597
#
#      Standard deviation/Mean of ladder by country-year  \
# 903                                           0.454318
# 904                                           0.406873
# 905                                           0.403504
# 906                                           0.410432
#
#      GINI index (World Bank estimate)  \
# 903                               NaN
# 904                               NaN
# 905                               NaN
# 906                               NaN
#
#      GINI index (World Bank estimate), average 2000-16  \
# 903                                           0.390167
# 904                                           0.390167
# 905                                           0.390167
# 906                                           0.390167
#
#      gini of household income reported in Gallup, by wp5-year  \
# 903                                           0.418142
# 904                                           0.524656
# 905                                           0.371204
# 906                                           0.340063
#
#      Most people can be trusted, Gallup  \
# 903                                 NaN
# 904                                 NaN
# 905                                 NaN
# 906                                 NaN
#
#      Most people can be trusted, WVS round 1981-1984  \
# 903                                              NaN
# 904                                              NaN
# 905                                              NaN
# 906                                              NaN
#
#      Most people can be trusted, WVS round 1989-1993  \
# 903                                              NaN
# 904                                              NaN
# 905                                              NaN
# 906                                              NaN
#
#      Most people can be trusted, WVS round 1994-1998  \
# 903                                         0.075377
# 904                                         0.075377
# 905                                         0.075377
# 906                                         0.075377
#
#      Most people can be trusted, WVS round 1999-2004  \
# 903                                         0.130688
# 904                                         0.130688
# 905                                         0.130688
# 906                                         0.130688
#
#      Most people can be trusted, WVS round 2005-2009  \
# 903                                              NaN
# 904                                              NaN
# 905                                              NaN
# 906                                              NaN
#
#      Most people can be trusted, WVS round 2010-2014 Continent
# 903                                              NaN    Europe
# 904                                              NaN    Europe
# 905                                              NaN    Europe
# 906                                              NaN    Europe

# %%
# Select which rows and columns to select:

data.iloc[903:907, 0:3]
# Out:
#     Country name  Year  Life Ladder
# 903    Macedonia  2015     4.975590
# 904    Macedonia  2016     5.345746
# 905    Macedonia  2017     5.233867
# 906    Macedonia  2018     5.239835

# %%
# Allow selecting rows (and columns) by:
# 1) label/index or
# 2) with boolean/conditional lookup

data.loc

# %%
# Set Country name as the dataframe's index:
data.set_index('Country name', inplace=True)

# %%
# Sets a new index on the DataFrame.

#set_index

# inplace=True -> Makes sure that the DataFrame will be changed.

data.sample(5)
# Out:
#               Year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Chad          2018     4.486325            7.472575        0.577254
# Burundi       2011     3.705894            6.648349        0.422240
# Cameroon      2018     5.250738            8.133471        0.676825
# Sri Lanka     2018     4.400223            9.400388        0.828065
# Serbia        2007     4.750384            9.409686        0.844413
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# Chad                                 48.200001                      0.650355
# Burundi                              50.680000                      0.489863
# Cameroon                             52.700001                      0.816305
# Sri Lanka                            67.199997                      0.852628
# Serbia                               65.599998                      0.452781
#
#               Generosity  Perceptions of corruption  Positive affect  \
# Country name
# Chad            0.011340                   0.762879         0.552737
# Burundi        -0.057828                   0.677108         0.688907
# Cameroon        0.032507                   0.884442         0.642437
# Sri Lanka       0.086762                   0.858017         0.831293
# Serbia         -0.167635                   0.904950         0.576048
#
#               Negative affect  Confidence in national government  \
# Country name
# Chad                 0.543836                           0.577436
# Burundi              0.190345                           0.851200
# Cameroon             0.355642                           0.645226
# Sri Lanka            0.301279                           0.576130
# Serbia               0.334420                           0.342911
#
#               Democratic Quality  Delivery Quality  \
# Country name
# Chad                         NaN               NaN
# Burundi                -1.367416         -1.100342
# Cameroon                     NaN               NaN
# Sri Lanka                    NaN               NaN
# Serbia                 -0.142877         -0.347605
#
#               Standard deviation of ladder by country-year  \
# Country name
# Chad                                              3.107621
# Burundi                                           1.745887
# Cameroon                                          2.921314
# Sri Lanka                                         2.356080
# Serbia                                            2.048377
#
#               Standard deviation/Mean of ladder by country-year  \
# Country name
# Chad                                                   0.692688
# Burundi                                                0.471111
# Cameroon                                               0.556363
# Sri Lanka                                              0.535446
# Serbia                                                 0.431202
#
#               GINI index (World Bank estimate)  \
# Country name
# Chad                                       NaN
# Burundi                                    NaN
# Cameroon                                   NaN
# Sri Lanka                                  NaN
# Serbia                                     NaN
#
#               GINI index (World Bank estimate), average 2000-16  \
# Country name
# Chad                                                   0.415500
# Burundi                                                0.360000
# Cameroon                                               0.438333
# Sri Lanka                                              0.393400
# Serbia                                                      NaN
#
#               gini of household income reported in Gallup, by wp5-year  \
# Country name
# Chad                                                   0.607655
# Burundi                                                0.646407
# Cameroon                                               0.521751
# Sri Lanka                                              0.408002
# Serbia                                                      NaN
#
#               Most people can be trusted, Gallup  \
# Country name
# Chad                                         NaN
# Burundi                                      NaN
# Cameroon                                     NaN
# Sri Lanka                                    NaN
# Serbia                                       NaN
#
#               Most people can be trusted, WVS round 1981-1984  \
# Country name
# Chad                                                      NaN
# Burundi                                                   NaN
# Cameroon                                                  NaN
# Sri Lanka                                                 NaN
# Serbia                                                    NaN
#
#               Most people can be trusted, WVS round 1989-1993  \
# Country name
# Chad                                                      NaN
# Burundi                                                   NaN
# Cameroon                                                  NaN
# Sri Lanka                                                 NaN
# Serbia                                                    NaN
#
#               Most people can be trusted, WVS round 1994-1998  \
# Country name
# Chad                                                      NaN
# Burundi                                                   NaN
# Cameroon                                                  NaN
# Sri Lanka                                                 NaN
# Serbia                                               0.284375
#
#               Most people can be trusted, WVS round 1999-2004  \
# Country name
# Chad                                                      NaN
# Burundi                                                   NaN
# Cameroon                                                  NaN
# Sri Lanka                                                 NaN
# Serbia                                               0.183333
#
#               Most people can be trusted, WVS round 2005-2009  \
# Country name
# Chad                                                      NaN
# Burundi                                                   NaN
# Cameroon                                                  NaN
# Sri Lanka                                                 NaN
# Serbia                                                    NaN
#
#               Most people can be trusted, WVS round 2010-2014 Continent
# Country name
# Chad                                                      NaN    Africa
# Burundi                                                   NaN    Africa
# Cameroon                                                  NaN    Africa
# Sri Lanka                                                 NaN      Asia
# Serbia                                                    NaN    Europe

# %%
# Can now see that the DataFrame lost its row numbers (the previous) index
# and gained a new index:

data.index
# Out:
# Index(['Afghanistan', 'Afghanistan', 'Afghanistan', 'Afghanistan',
#        'Afghanistan', 'Afghanistan', 'Afghanistan', 'Afghanistan',
#        'Afghanistan', 'Afghanistan',
#        ...
#        'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe',
#        'Zimbabwe', 'Zimbabwe', 'Zimbabwe', 'Zimbabwe'],
#       dtype='object', name='Country name', length=1704)

# %%
# loc - Selecting row(s) by one index label:

# Syntax: data.loc[index_label (,col_label)]

data.loc['United States']
# Out:
#                Year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# United States  2006     7.181794           10.831686        0.964572
# United States  2007     7.512688           10.839805             NaN
# United States  2008     7.280386           10.827426        0.952587
# United States  2009     7.158032           10.790511        0.911794
# ...             ...          ...                 ...             ...
# United States  2015     6.863947           10.878154        0.903571
# United States  2016     6.803600           10.885554        0.896751
# United States  2017     6.991759           10.900906        0.921003
# United States  2018     6.882685           10.922465        0.903856
#
#                Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# United States                         68.059998                      0.911496
# United States                         68.220001                      0.871904
# United States                         68.379997                      0.877956
# United States                         68.540001                      0.830684
# ...                                         ...                           ...
# United States                         68.599998                      0.848753
# United States                         68.500000                      0.757893
# United States                         68.400002                      0.868497
# United States                         68.300003                      0.824607
#
#                Generosity  Perceptions of corruption  Positive affect  \
# Country name
# United States         NaN                   0.600309         0.827417
# United States    0.188272                   0.633035         0.828503
# United States    0.246029                   0.668495         0.871968
# United States    0.192269                   0.665394         0.843484
# ...                   ...                        ...              ...
# United States    0.210956                   0.697543         0.813908
# United States    0.135592                   0.738920         0.805674
# United States    0.188833                   0.681191         0.826555
# United States    0.107713                   0.709928         0.815383
#
#                Negative affect  Confidence in national government  \
# Country name
# United States         0.260511                           0.558029
# United States         0.231679                           0.393245
# United States         0.226823                           0.379221
# United States         0.261661                           0.503047
# ...                        ...                                ...
# United States         0.274688                           0.346936
# United States         0.264204                           0.297206
# United States         0.268269                           0.386535
# United States         0.292226                           0.313816
#
#                Democratic Quality  Delivery Quality  \
# Country name
# United States            0.797783          1.546490
# United States            0.742770          1.539012
# United States            0.864745          1.559145
# United States            0.772818          1.450143
# ...                           ...               ...
# United States            0.893903          1.428245
# United States            0.755765          1.491426
# United States            0.677056          1.552135
# United States                 NaN               NaN
#
#                Standard deviation of ladder by country-year  \
# Country name
# United States                                      1.873673
# United States                                      1.723988
# United States                                      1.778600
# United States                                      2.021277
# ...                                                     ...
# United States                                      1.953670
# United States                                      1.972203
# United States                                      1.880688
# United States                                      2.119374
#
#                Standard deviation/Mean of ladder by country-year  \
# Country name
# United States                                           0.260892
# United States                                           0.229477
# United States                                           0.244300
# United States                                           0.282379
# ...                                                          ...
# United States                                           0.284628
# United States                                           0.289876
# United States                                           0.268986
# United States                                           0.307928
#
#                GINI index (World Bank estimate)  \
# Country name
# United States                               NaN
# United States                             0.411
# United States                               NaN
# United States                               NaN
# ...                                         ...
# United States                               NaN
# United States                             0.415
# United States                               NaN
# United States                               NaN
#
#                GINI index (World Bank estimate), average 2000-16  \
# Country name
# United States                                           0.408167
# United States                                           0.408167
# United States                                           0.408167
# United States                                           0.408167
# ...                                                          ...
# United States                                           0.408167
# United States                                           0.408167
# United States                                           0.408167
# United States                                           0.408167
#
#                gini of household income reported in Gallup, by wp5-year  \
# Country name
# United States                                                NaN
# United States                                                NaN
# United States                                                NaN
# United States                                           0.705702
# ...                                                          ...
# United States                                           0.649792
# United States                                           0.693315
# United States                                           0.610804
# United States                                           0.701418
#
#                Most people can be trusted, Gallup  \
# Country name
# United States                                 NaN
# United States                                 NaN
# United States                                 NaN
# United States                            0.370746
# ...                                           ...
# United States                                 NaN
# United States                                 NaN
# United States                                 NaN
# United States                                 NaN
#
#                Most people can be trusted, WVS round 1981-1984  \
# Country name
# United States                                         0.453548
# United States                                         0.453548
# United States                                         0.453548
# United States                                         0.453548
# ...                                                        ...
# United States                                         0.453548
# United States                                         0.453548
# United States                                         0.453548
# United States                                         0.453548
#
#                Most people can be trusted, WVS round 1989-1993  \
# Country name
# United States                                              NaN
# United States                                              NaN
# United States                                              NaN
# United States                                              NaN
# ...                                                        ...
# United States                                              NaN
# United States                                              NaN
# United States                                              NaN
# United States                                              NaN
#
#                Most people can be trusted, WVS round 1994-1998  \
# Country name
# United States                                         0.349513
# United States                                         0.349513
# United States                                         0.349513
# United States                                         0.349513
# ...                                                        ...
# United States                                         0.349513
# United States                                         0.349513
# United States                                         0.349513
# United States                                         0.349513
#
#                Most people can be trusted, WVS round 1999-2004  \
# Country name
# United States                                         0.355185
# United States                                         0.355185
# United States                                         0.355185
# United States                                         0.355185
# ...                                                        ...
# United States                                         0.355185
# United States                                         0.355185
# United States                                         0.355185
# United States                                         0.355185
#
#                Most people can be trusted, WVS round 2005-2009  \
# Country name
# United States                                         0.393451
# United States                                         0.393451
# United States                                         0.393451
# United States                                         0.393451
# ...                                                        ...
# United States                                         0.393451
# United States                                         0.393451
# United States                                         0.393451
# United States                                         0.393451
#
#                Most people can be trusted, WVS round 2010-2014      Continent
# Country name
# United States                                         0.351395  North America
# United States                                         0.351395  North America
# United States                                         0.351395  North America
# United States                                         0.351395  North America
# ...                                                        ...            ...
# United States                                         0.351395  North America
# United States                                         0.351395  North America
# United States                                         0.351395  North America
# United States                                         0.351395  North America
#
# [13 rows x 26 columns]

# %%
# Selecting rows and column by index lable and column label:
data.loc['United States', 'Life Ladder']
# Out:
# Country name
# United States    7.181794
# United States    7.512688
# United States    7.280386
# United States    7.158032
#                    ...
# United States    6.863947
# United States    6.803600
# United States    6.991759
# United States    6.882685
# Name: Life Ladder, Length: 13, dtype: float64

# %%
data.loc[['United States','Germany']].sample(5)
# Out:
#                Year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Germany        2018     7.118364           10.730945        0.919763
# Germany        2014     6.984214           10.681909        0.937559
# United States  2014     7.151114           10.857497        0.902097
# United States  2015     6.863947           10.878154        0.903571
# Germany        2010     6.724531           10.607296        0.939309
#
#                Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# Germany                               72.199997                      0.876888
# Germany                               71.220001                      0.898683
# United States                         68.620003                      0.866077
# United States                         68.599998                      0.848753
# Germany                               70.900002                      0.842656
#
#                Generosity  Perceptions of corruption  Positive affect  \
# Country name
# Germany          0.030200                   0.495674         0.780280
# Germany          0.083834                   0.473953         0.785408
# United States    0.212869                   0.702267         0.834294
# United States    0.210956                   0.697543         0.813908
# Germany          0.091027                   0.688006         0.793706
#
#                Negative affect  Confidence in national government  \
# Country name
# Germany               0.243215                           0.592991
# Germany               0.187845                           0.601369
# United States         0.281265                           0.348671
# United States         0.274688                           0.346936
# Germany               0.182344                           0.395424
#
#                Democratic Quality  Delivery Quality  \
# Country name
# Germany                       NaN               NaN
# Germany                  1.180758          1.782412
# United States            0.826821          1.433888
# United States            0.893903          1.428245
# Germany                  1.047309          1.637933
#
#                Standard deviation of ladder by country-year  \
# Country name
# Germany                                            1.623589
# Germany                                            1.664546
# United States                                      2.070654
# United States                                      1.953670
# Germany                                            1.861712
#
#                Standard deviation/Mean of ladder by country-year  \
# Country name
# Germany                                                 0.228085
# Germany                                                 0.238330
# United States                                           0.289557
# United States                                           0.284628
# Germany                                                 0.276854
#
#                GINI index (World Bank estimate)  \
# Country name
# Germany                                     NaN
# Germany                                     NaN
# United States                               NaN
# United States                               NaN
# Germany                                   0.302
#
#                GINI index (World Bank estimate), average 2000-16  \
# Country name
# Germany                                                 0.306222
# Germany                                                 0.306222
# United States                                           0.408167
# United States                                           0.408167
# Germany                                                 0.306222
#
#                gini of household income reported in Gallup, by wp5-year  \
# Country name
# Germany                                                 0.283513
# Germany                                                 0.454418
# United States                                           0.753396
# United States                                           0.649792
# Germany                                                 0.465919
#
#                Most people can be trusted, Gallup  \
# Country name
# Germany                                       NaN
# Germany                                       NaN
# United States                                 NaN
# United States                                 NaN
# Germany                                       NaN
#
#                Most people can be trusted, WVS round 1981-1984  \
# Country name
# Germany                                                    NaN
# Germany                                                    NaN
# United States                                         0.453548
# United States                                         0.453548
# Germany                                                    NaN
#
#                Most people can be trusted, WVS round 1989-1993  \
# Country name
# Germany                                                    NaN
# Germany                                                    NaN
# United States                                              NaN
# United States                                              NaN
# Germany                                                    NaN
#
#                Most people can be trusted, WVS round 1994-1998  \
# Country name
# Germany                                               0.321323
# Germany                                               0.321323
# United States                                         0.349513
# United States                                         0.349513
# Germany                                               0.321323
#
#                Most people can be trusted, WVS round 1999-2004  \
# Country name
# Germany                                                    NaN
# Germany                                                    NaN
# United States                                         0.355185
# United States                                         0.355185
# Germany                                                    NaN
#
#                Most people can be trusted, WVS round 2005-2009  \
# Country name
# Germany                                               0.343591
# Germany                                               0.343591
# United States                                         0.393451
# United States                                         0.393451
# Germany                                               0.343591
#
#                Most people can be trusted, WVS round 2010-2014      Continent
# Country name
# Germany                                               0.447488         Europe
# Germany                                               0.447488         Europe
# United States                                         0.351395  North America
# United States                                         0.351395  North America
# Germany                                               0.447488         Europe

# %%
# Selecting rows and columns by multiple index labels:

# You can also specify the column names for the selected rows
# That you want to return.

data.loc[
    ['Germany','United States'],#Row Indices
    ['Year','Life Ladder']#Column Indices
].sample(5)
# NOTE: Splitting statement into two lines makes for better readability.
# Out:
#                Year  Life Ladder
# Country name
# Germany        2011     6.621312
# Germany        2017     7.074325
# United States  2016     6.803600
# Germany        2013     6.965125
# Germany        2016     6.873763

# %%
# Selecting row(s) by a range of index labels:

# ('Denmark':'Germany') vs. ('903:907') for iloc.

# Assume your index is sorted, or you sorted it before selecting a range,
# Can do the following:

data.loc[
    'Denmark':'Germany',
    ['Year','Life Ladder']
].sample(5)
# Out:
#               Year  Life Ladder
# Country name
# Ethiopia      2015     4.573155
# El Salvador   2007     5.295535
# Georgia       2014     4.287508
# Denmark       2015     7.514425
# Denmark       2018     7.648786

# %%
# loc - boolean/conditional lookup

# Boolean or conditional lookup is where the meat is.
# Whenever selecting row, this happens by overlaying the DataFrame
# Of True and False values.

# In the following example,
# Create a small DataFrame with the index:
# ['A', 'B', 'A', 'D']
# and some random values between 0 and 10 as values.

# Then, create an overlay with the same Index with the values:
# [True, False, True, False]..

# Use df.loc[overlay] to only select the rows with True value for their index.

from numpy.random import randint
index = ['A', 'B', 'A', 'D']

## Create dummy DataFrame ##

df = pd.DataFrame(
    index = index,
    data = {
        'values' :randint(10, size=len(index))
})
print('DataFrame:')
print(df)
# Out:
# DataFrame:
#    values
# A       4
# B       5
# A       8
# D       9

# %%
## Create dummy overlay ##
overlay = pd.Series(
    index = index,
    data = [True, False, True, False]
)
print('\n Overlay:')
print(overlay)
# Out:
#  Overlay:
# A     True
# B    False
# A     True
# D    False
# dtype: bool

# %%
## Select only True rows ##
print('\nMasked DataFrame:')
print(df.loc[overlay])
# Out:
# Masked DataFrame:
#    values
# A       4
# A       8

# %%
# Same logic -> Select rows based on a (or multiple) condition(s).

# First create a boolean mask like this:
data['Life Ladder'] > 4
# Out:
# Country name
# Afghanistan    False
# Afghanistan     True
# Afghanistan     True
# Afghanistan    False
#                ...
# Zimbabwe       False
# Zimbabwe       False
# Zimbabwe       False
# Zimbabwe       False
# Name: Life Ladder, Length: 1704, dtype: bool

# %%
# Use mask to only select the rows that meet the specified condition
# Like this:

# Option 1:
data.loc[data['Life Ladder'] > 4]

# Alternative:
#condition = data['Life ladder'] > 4
#data.loc[condition]
# Out:
#               Year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Afghanistan   2009     4.401778            7.333790        0.552308
# Afghanistan   2010     4.758381            7.386629        0.539075
# Afghanistan   2016     4.220169            7.497038        0.559072
# Albania       2007     4.634252            9.077331        0.821372
# ...            ...          ...                 ...             ...
# Zimbabwe      2011     4.845642            7.418864        0.864694
# Zimbabwe      2012     4.955101            7.534424        0.896476
# Zimbabwe      2013     4.690188            7.565154        0.799274
# Zimbabwe      2014     4.184451            7.562753        0.765839
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# Afghanistan                          51.200001                      0.678896
# Afghanistan                          51.599998                      0.600127
# Afghanistan                          53.000000                      0.522566
# Albania                              65.800003                      0.528605
# ...                                        ...                           ...
# Zimbabwe                             48.119999                      0.632978
# Zimbabwe                             49.540001                      0.469531
# Zimbabwe                             50.959999                      0.575884
# Zimbabwe                             52.380001                      0.642034
#
#               Generosity  Perceptions of corruption  Positive affect  \
# Country name
# Afghanistan     0.200178                   0.850035         0.583926
# Afghanistan     0.134353                   0.706766         0.618265
# Afghanistan     0.051365                   0.793246         0.564953
# Albania        -0.014393                   0.874700         0.552678
# ...                  ...                        ...              ...
# Zimbabwe       -0.062267                   0.829800         0.781189
# Zimbabwe       -0.075712                   0.858691         0.669279
# Zimbabwe       -0.079458                   0.830937         0.711885
# Zimbabwe       -0.048634                   0.820217         0.725214
#
#               Negative affect  Confidence in national government  \
# Country name
# Afghanistan          0.237092                           0.611545
# Afghanistan          0.275324                           0.299357
# Afghanistan          0.348332                           0.324990
# Albania              0.246335                           0.300681
# ...                       ...                                ...
# Zimbabwe             0.210544                           0.425926
# Zimbabwe             0.177311                           0.407084
# Zimbabwe             0.182288                           0.527755
# Zimbabwe             0.239111                           0.566209
#
#               Democratic Quality  Delivery Quality  \
# Country name
# Afghanistan            -2.044093         -1.635025
# Afghanistan            -1.991810         -1.617176
# Afghanistan            -1.855426         -1.392713
# Albania                -0.045108         -0.420024
# ...                          ...               ...
# Zimbabwe               -1.204545         -1.621979
# Zimbabwe               -1.125315         -1.555728
# Zimbabwe               -1.026085         -1.526321
# Zimbabwe               -0.985267         -1.484067
#
#               Standard deviation of ladder by country-year  \
# Country name
# Afghanistan                                       1.722688
# Afghanistan                                       1.878622
# Afghanistan                                       1.796219
# Albania                                           1.764947
# ...                                                    ...
# Zimbabwe                                          1.760146
# Zimbabwe                                          1.853195
# Zimbabwe                                          1.964805
# Zimbabwe                                          2.079248
#
#               Standard deviation/Mean of ladder by country-year  \
# Country name
# Afghanistan                                            0.391362
# Afghanistan                                            0.394803
# Afghanistan                                            0.425627
# Albania                                                0.380848
# ...                                                         ...
# Zimbabwe                                               0.363243
# Zimbabwe                                               0.373997
# Zimbabwe                                               0.418918
# Zimbabwe                                               0.496899
#
#               GINI index (World Bank estimate)  \
# Country name
# Afghanistan                                NaN
# Afghanistan                                NaN
# Afghanistan                                NaN
# Albania                                    NaN
# ...                                        ...
# Zimbabwe                                 0.432
# Zimbabwe                                   NaN
# Zimbabwe                                   NaN
# Zimbabwe                                   NaN
#
#               GINI index (World Bank estimate), average 2000-16  \
# Country name
# Afghanistan                                                 NaN
# Afghanistan                                                 NaN
# Afghanistan                                                 NaN
# Albania                                                 0.30325
# ...                                                         ...
# Zimbabwe                                                0.43200
# Zimbabwe                                                0.43200
# Zimbabwe                                                0.43200
# Zimbabwe                                                0.43200
#
#               gini of household income reported in Gallup, by wp5-year  \
# Country name
# Afghanistan                                            0.441906
# Afghanistan                                            0.327318
# Afghanistan                                            0.418629
# Albania                                                     NaN
# ...                                                         ...
# Zimbabwe                                               0.514646
# Zimbabwe                                               0.487203
# Zimbabwe                                               0.555439
# Zimbabwe                                               0.601080
#
#               Most people can be trusted, Gallup  \
# Country name
# Afghanistan                             0.286315
# Afghanistan                             0.275833
# Afghanistan                                  NaN
# Albania                                      NaN
# ...                                          ...
# Zimbabwe                                     NaN
# Zimbabwe                                     NaN
# Zimbabwe                                     NaN
# Zimbabwe                                     NaN
#
#               Most people can be trusted, WVS round 1981-1984  \
# Country name
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Albania                                                   NaN
# ...                                                       ...
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
#
#               Most people can be trusted, WVS round 1989-1993  \
# Country name
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Albania                                                   NaN
# ...                                                       ...
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
#
#               Most people can be trusted, WVS round 1994-1998  \
# Country name
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Albania                                              0.243243
# ...                                                       ...
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
#
#               Most people can be trusted, WVS round 1999-2004  \
# Country name
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Albania                                              0.232000
# ...                                                       ...
# Zimbabwe                                             0.116683
# Zimbabwe                                             0.116683
# Zimbabwe                                             0.116683
# Zimbabwe                                             0.116683
#
#               Most people can be trusted, WVS round 2005-2009  \
# Country name
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Afghanistan                                               NaN
# Albania                                                   NaN
# ...                                                       ...
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
# Zimbabwe                                                  NaN
#
#               Most people can be trusted, WVS round 2010-2014 Continent
# Country name
# Afghanistan                                               NaN      Asia
# Afghanistan                                               NaN      Asia
# Afghanistan                                               NaN      Asia
# Albania                                                   NaN    Europe
# ...                                                       ...       ...
# Zimbabwe                                             0.082942    Africa
# Zimbabwe                                             0.082942    Africa
# Zimbabwe                                             0.082942    Africa
# Zimbabwe                                             0.082942    Africa
#
# [1534 rows x 26 columns]

# %%
# Option 1, as well as, the alternative yield precisely the same result.
# However, the alternative is a little more legible.
# The improved legibility becomes even more apparent when applying
# Multiple conditions:

life_condition = data['Life Ladder'] > 4
year_condition = data['Year'] > 2014
social_condition = data['Social support'] > .5

# %%
data.loc[life_condition & year_condition & social_condition]
# Out:
#               Year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Afghanistan   2016     4.220169            7.497038        0.559072
# Albania       2015     4.606651            9.302960        0.639356
# Albania       2016     4.511101            9.337532        0.638411
# Albania       2017     4.639548            9.376145        0.637698
# ...            ...          ...                 ...             ...
# Vietnam       2018     5.295547            8.783416        0.831945
# Zambia        2015     4.843164            8.196217        0.691483
# Zambia        2016     4.347544            8.203072        0.767047
# Zambia        2018     4.041488            8.223958        0.717720
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# Afghanistan                          53.000000                      0.522566
# Albania                              67.800003                      0.703851
# Albania                              68.099998                      0.729819
# Albania                              68.400002                      0.749611
# ...                                        ...                           ...
# Vietnam                              67.900002                      0.909260
# Zambia                               53.799999                      0.758654
# Zambia                               54.299999                      0.811575
# Zambia                               55.299999                      0.790626
#
#               Generosity  Perceptions of corruption  Positive affect  \
# Country name
# Afghanistan     0.051365                   0.793246         0.564953
# Albania        -0.084411                   0.884793         0.688370
# Albania        -0.020687                   0.901071         0.675244
# Albania        -0.032643                   0.876135         0.669241
# ...                  ...                        ...              ...
# Vietnam        -0.039124                   0.808423         0.692222
# Zambia         -0.049828                   0.871020         0.690034
# Zambia          0.111332                   0.770644         0.730680
# Zambia          0.036644                   0.810731         0.702698
#
#               Negative affect  Confidence in national government  \
# Country name
# Afghanistan          0.348332                           0.324990
# Albania              0.350427                           0.506978
# Albania              0.321706                           0.400910
# Albania              0.333884                           0.457738
# ...                       ...                                ...
# Vietnam              0.191061                                NaN
# Zambia               0.381731                           0.631103
# Zambia               0.372241                           0.696892
# Zambia               0.350963                           0.606715
#
#               Democratic Quality  Delivery Quality  \
# Country name
# Afghanistan            -1.855426         -1.392713
# Albania                 0.251629         -0.152544
# Albania                 0.257292         -0.134950
# Albania                 0.299945         -0.130315
# ...                          ...               ...
# Vietnam                      NaN               NaN
# Zambia                  0.040718         -0.391482
# Zambia                 -0.083534         -0.460275
# Zambia                       NaN               NaN
#
#               Standard deviation of ladder by country-year  \
# Country name
# Afghanistan                                       1.796219
# Albania                                           2.729001
# Albania                                           2.646668
# Albania                                           2.682105
# ...                                                    ...
# Vietnam                                           1.676448
# Zambia                                            3.080448
# Zambia                                            3.197226
# Zambia                                            2.783419
#
#               Standard deviation/Mean of ladder by country-year  \
# Country name
# Afghanistan                                            0.425627
# Albania                                                0.592405
# Albania                                                0.586701
# Albania                                                0.578096
# ...                                                         ...
# Vietnam                                                0.316577
# Zambia                                                 0.636040
# Zambia                                                 0.735410
# Zambia                                                 0.688711
#
#               GINI index (World Bank estimate)  \
# Country name
# Afghanistan                                NaN
# Albania                                    NaN
# Albania                                    NaN
# Albania                                    NaN
# ...                                        ...
# Vietnam                                    NaN
# Zambia                                   0.571
# Zambia                                     NaN
# Zambia                                     NaN
#
#               GINI index (World Bank estimate), average 2000-16  \
# Country name
# Afghanistan                                                 NaN
# Albania                                                 0.30325
# Albania                                                 0.30325
# Albania                                                 0.30325
# ...                                                         ...
# Vietnam                                                 0.36275
# Zambia                                                  0.52740
# Zambia                                                  0.52740
# Zambia                                                  0.52740
#
#               gini of household income reported in Gallup, by wp5-year  \
# Country name
# Afghanistan                                            0.418629
# Albania                                                0.422627
# Albania                                                0.416540
# Albania                                                0.410488
# ...                                                         ...
# Vietnam                                                0.415666
# Zambia                                                 0.671201
# Zambia                                                 0.681393
# Zambia                                                 0.619443
#
#               Most people can be trusted, Gallup  \
# Country name
# Afghanistan                                  NaN
# Albania                                      NaN
# Albania                                      NaN
# Albania                                      NaN
# ...                                          ...
# Vietnam                                      NaN
# Zambia                                       NaN
# Zambia                                       NaN
# Zambia                                       NaN
#
#               Most people can be trusted, WVS round 1981-1984  \
# Country name
# Afghanistan                                               NaN
# Albania                                                   NaN
# Albania                                                   NaN
# Albania                                                   NaN
# ...                                                       ...
# Vietnam                                                   NaN
# Zambia                                                    NaN
# Zambia                                                    NaN
# Zambia                                                    NaN
#
#               Most people can be trusted, WVS round 1989-1993  \
# Country name
# Afghanistan                                               NaN
# Albania                                                   NaN
# Albania                                                   NaN
# Albania                                                   NaN
# ...                                                       ...
# Vietnam                                                   NaN
# Zambia                                                    NaN
# Zambia                                                    NaN
# Zambia                                                    NaN
#
#               Most people can be trusted, WVS round 1994-1998  \
# Country name
# Afghanistan                                               NaN
# Albania                                              0.243243
# Albania                                              0.243243
# Albania                                              0.243243
# ...                                                       ...
# Vietnam                                                   NaN
# Zambia                                                    NaN
# Zambia                                                    NaN
# Zambia                                                    NaN
#
#               Most people can be trusted, WVS round 1999-2004  \
# Country name
# Afghanistan                                               NaN
# Albania                                                 0.232
# Albania                                                 0.232
# Albania                                                 0.232
# ...                                                       ...
# Vietnam                                                 0.387
# Zambia                                                    NaN
# Zambia                                                    NaN
# Zambia                                                    NaN
#
#               Most people can be trusted, WVS round 2005-2009  \
# Country name
# Afghanistan                                               NaN
# Albania                                                   NaN
# Albania                                                   NaN
# Albania                                                   NaN
# ...                                                       ...
# Vietnam                                              0.510054
# Zambia                                               0.110429
# Zambia                                               0.110429
# Zambia                                               0.110429
#
#               Most people can be trusted, WVS round 2010-2014 Continent
# Country name
# Afghanistan                                               NaN      Asia
# Albania                                                   NaN    Europe
# Albania                                                   NaN    Europe
# Albania                                                   NaN    Europe
# ...                                                       ...       ...
# Vietnam                                                   NaN      Asia
# Zambia                                                    NaN    Africa
# Zambia                                                    NaN    Africa
# Zambia                                                    NaN    Africa
#
# [507 rows x 26 columns]

# %%
# NOTE: We used & (bitwise and) to filter for rows s.t. multiple conditions
# Apply at the same time.
# Can use | (bitwise or) to filter for columns, where one of the conditions
# Applies.

# %%
# Advanced Conditional Lookup with Custom Formulas

# It is also possible and quite easy to use customized functions as
# A condition and apply them to select columns.

# In the following example,
# We only select years that are cleanly divisible by three and 
# Continents that contain the word America.
# The case is contrived but makes a point.

cond_year = data['Year'].apply(lambda x: x%3 == 0)
cond_america = data['Continent'].apply(lambda x: 'America' in x)

data[cond_year & cond_america]
# Out:
#               Year  Life Ladder  Log GDP per capita  Social support  \
# Country name
# Argentina     2007     6.073158            9.792596        0.862206
# Argentina     2010     6.441067            9.836924        0.926799
# Argentina     2013     6.582260            9.877256        0.909874
# Argentina     2016     6.427221            9.830088        0.882819
# ...            ...          ...                 ...             ...
# Uruguay       2016     6.171485            9.908158        0.900381
# Venezuela     2010     7.478455            9.713838        0.931576
# Venezuela     2013     6.552796            9.779354        0.896301
# Venezuela     2016     4.041115            9.534059        0.901949
#
#               Healthy life expectancy at birth  Freedom to make life choices  \
# Country name
# Argentina                            66.940002                      0.652833
# Argentina                            67.300003                      0.730258
# Argentina                            67.839996                      0.737250
# Argentina                            68.400002                      0.847702
# ...                                        ...                           ...
# Uruguay                              68.800003                      0.886372
# Venezuela                            65.699997                      0.768257
# Venezuela                            65.820000                      0.641965
# Venezuela                            66.099998                      0.457602
#
#               Generosity  Perceptions of corruption  Positive affect  \
# Country name
# Argentina      -0.136928                   0.881058         0.827920
# Argentina      -0.121725                   0.854695         0.846136
# Argentina      -0.126476                   0.822900         0.842479
# Argentina      -0.188304                   0.850924         0.841907
# ...                  ...                        ...              ...
# Uruguay        -0.081855                   0.676213         0.841549
# Venezuela      -0.166679                   0.754269         0.861522
# Venezuela      -0.234825                   0.837300         0.839730
# Venezuela      -0.203748                   0.890125         0.688201
#
#               Negative affect  Confidence in national government  \
# Country name
# Argentina            0.279008                           0.405824
# Argentina            0.210975                           0.351856
# Argentina            0.254205                           0.433749
# Argentina            0.311646                           0.419562
# ...                       ...                                ...
# Uruguay              0.283180                           0.423133
# Venezuela            0.129686                           0.588830
# Venezuela            0.237609                           0.388056
# Venezuela            0.391754                           0.164022
#
#               Democratic Quality  Delivery Quality  \
# Country name
# Argentina               0.273740         -0.404018
# Argentina               0.138446         -0.469284
# Argentina               0.171151         -0.593692
# Argentina               0.348582         -0.243653
# ...                          ...               ...
# Uruguay                 1.112749          0.736727
# Venezuela              -1.063392         -1.404303
# Venezuela              -1.014605         -1.483182
# Venezuela              -1.080577         -1.719712
#
#               Standard deviation of ladder by country-year  \
# Country name
# Argentina                                         2.039103
# Argentina                                         2.107838
# Argentina                                         1.992898
# Argentina                                         2.127109
# ...                                                    ...
# Uruguay                                           2.318233
# Venezuela                                         2.289491
# Venezuela                                         2.474761
# Venezuela                                         2.649300
#
#               Standard deviation/Mean of ladder by country-year  \
# Country name
# Argentina                                              0.335757
# Argentina                                              0.327250
# Argentina                                              0.302768
# Argentina                                              0.330953
# ...                                                         ...
# Uruguay                                                0.375636
# Venezuela                                              0.306145
# Venezuela                                              0.377665
# Venezuela                                              0.655586
#
#               GINI index (World Bank estimate)  \
# Country name
# Argentina                                0.463
# Argentina                                0.430
# Argentina                                0.410
# Argentina                                0.424
# ...                                        ...
# Uruguay                                  0.397
# Venezuela                                  NaN
# Venezuela                                  NaN
# Venezuela                                  NaN
#
#               GINI index (World Bank estimate), average 2000-16  \
# Country name
# Argentina                                              0.460938
# Argentina                                              0.460938
# Argentina                                              0.460938
# Argentina                                              0.460938
# ...                                                         ...
# Uruguay                                                0.427364
# Venezuela                                              0.497167
# Venezuela                                              0.497167
# Venezuela                                              0.497167
#
#               gini of household income reported in Gallup, by wp5-year  \
# Country name
# Argentina                                                   NaN
# Argentina                                              0.366742
# Argentina                                              0.362593
# Argentina                                              0.332071
# ...                                                         ...
# Uruguay                                                0.428163
# Venezuela                                              0.313196
# Venezuela                                              0.275068
# Venezuela                                              0.397183
#
#               Most people can be trusted, Gallup  \
# Country name
# Argentina                                    NaN
# Argentina                               0.228952
# Argentina                                    NaN
# Argentina                                    NaN
# ...                                          ...
# Uruguay                                      NaN
# Venezuela                               0.129567
# Venezuela                                    NaN
# Venezuela                                    NaN
#
#               Most people can be trusted, WVS round 1981-1984  \
# Country name
# Argentina                                            0.270073
# Argentina                                            0.270073
# Argentina                                            0.270073
# Argentina                                            0.270073
# ...                                                       ...
# Uruguay                                                   NaN
# Venezuela                                                 NaN
# Venezuela                                                 NaN
# Venezuela                                                 NaN
#
#               Most people can be trusted, WVS round 1989-1993  \
# Country name
# Argentina                                            0.223553
# Argentina                                            0.223553
# Argentina                                            0.223553
# Argentina                                            0.223553
# ...                                                       ...
# Uruguay                                                   NaN
# Venezuela                                                 NaN
# Venezuela                                                 NaN
# Venezuela                                                 NaN
#
#               Most people can be trusted, WVS round 1994-1998  \
# Country name
# Argentina                                            0.170844
# Argentina                                            0.170844
# Argentina                                            0.170844
# Argentina                                            0.170844
# ...                                                       ...
# Uruguay                                              0.216405
# Venezuela                                            0.133333
# Venezuela                                            0.133333
# Venezuela                                            0.133333
#
#               Most people can be trusted, WVS round 1999-2004  \
# Country name
# Argentina                                            0.150154
# Argentina                                            0.150154
# Argentina                                            0.150154
# Argentina                                            0.150154
# ...                                                       ...
# Uruguay                                                   NaN
# Venezuela                                            0.158333
# Venezuela                                            0.158333
# Venezuela                                            0.158333
#
#               Most people can be trusted, WVS round 2005-2009  \
# Country name
# Argentina                                            0.174058
# Argentina                                            0.174058
# Argentina                                            0.174058
# Argentina                                            0.174058
# ...                                                       ...
# Uruguay                                              0.284393
# Venezuela                                                 NaN
# Venezuela                                                 NaN
# Venezuela                                                 NaN
#
#               Most people can be trusted, WVS round 2010-2014      Continent
# Country name
# Argentina                                            0.193531  South America
# Argentina                                            0.193531  South America
# Argentina                                            0.193531  South America
# Argentina                                            0.193531  South America
# ...                                                       ...            ...
# Uruguay                                              0.144351  South America
# Venezuela                                                 NaN  South America
# Venezuela                                                 NaN  South America
# Venezuela                                                 NaN  South America
#
# [86 rows x 26 columns]

# %%
# Argentina -> Venezuela: Countries in NORTH and SOUTH America.

# Instead of lambda (anonymous) functions,
# You could also define and use much more complicated functions.
# Could even (not that I recommend it) make API calls
# in a custom function and use the results of the calls to filter your dataframe.

# %%
# 4) Analytical Functions

# Now that we are comfortable with filtering and sorting the data front
# To back and vice versa, let's move to some more advanced analytical
# Functionalities.

# %%
# Standard Functions:

# Like the read functions,
# There are also a lot of analytical functions implemented in Pandas.

# I will highlight and explain the ones that I use most frequently.

# Used most frequently:

# However, and that's part of the beauty of it, even I will
# Find new useful functions from time to time.

# So, never stop reading and exploring!

# 1) max/min

# 2) sum

# 3) mean/median/quantile

# 4) idxmin/idxmax

# NOTE: All functions can be applied column-wise, but also row-wise.

# - The row-wise application makes very little sense in our example.

# - However, frequently, you have data, where you want to compare

# Different columns, in which case, the row-wise application does make sense.

# Whenever we call the aforementioned functions,

# axis=0 - is passed (for column-wise application).

# However, we can override this parameter and pass 

# axis=1 (for row-wise application).

# %%
# Calling max/min:

# Calling max() on data,

# - Will return (wherever possible) the maximum for each column.

# min() does the exact opposite.

# %%
data.max() # COLUMNWISE MAXIMUM
# Out:
# Year                                                        2018
# Life Ladder                                              8.01893
# Log GDP per capita                                       11.7703
# Social support                                          0.987343
#                                                        ...
# Most people can be trusted, WVS round 1999-2004         0.637185
# Most people can be trusted, WVS round 2005-2009         0.737305
# Most people can be trusted, WVS round 2010-2014         0.661757
# Continent                                          South America
# Length: 26, dtype: object

# %%
data.max(axis=1) # ROW-WISE MAXIMUM
# Out:
# Country name
# Afghanistan    2008.0
# Afghanistan    2009.0
# Afghanistan    2010.0
# Afghanistan    2011.0
#                 ...
# Zimbabwe       2015.0
# Zimbabwe       2016.0
# Zimbabwe       2017.0
# Zimbabwe       2018.0
# Length: 1704, dtype: float64

# %%
data.sum() # Will return (wherever possible) the sum for each column.
# Out:
# Year                                                                                         3429014
# Life Ladder                                                                                  9264.91
# Log GDP per capita                                                                           15456.8
# Social support                                                                               1370.67
#                                                                          ...
# Most people can be trusted, WVS round 1999-2004                                              131.623
# Most people can be trusted, WVS round 2005-2009                                              166.532
# Most people can be trusted, WVS round 2010-2014                                              159.358
# Continent                                          AsiaAsiaAsiaAsiaAsiaAsiaAsiaAsiaAsiaAsiaAsiaEu...
# Length: 26, dtype: object

# %%
data.mean()
# Out:
# Year                                               2012.332160
# Life Ladder                                           5.437155
# Log GDP per capita                                    9.222456
# Social support                                        0.810570
#                                                       ...
# Most people can be trusted, WVS round 1994-1998       0.249574
# Most people can be trusted, WVS round 1999-2004       0.268070
# Most people can be trusted, WVS round 2005-2009       0.264336
# Most people can be trusted, WVS round 2010-2014       0.237493
# Length: 25, dtype: float64

# %%
data.median()
# Out:
# Year                                               2012.000000
# Life Ladder                                           5.339557
# Log GDP per capita                                    9.406206
# Social support                                        0.833098
#                                                       ...
# Most people can be trusted, WVS round 1994-1998       0.229924
# Most people can be trusted, WVS round 1999-2004       0.232000
# Most people can be trusted, WVS round 2005-2009       0.198380
# Most people can be trusted, WVS round 2010-2014       0.193531
# Length: 25, dtype: float64

# %%
data.quantile(q=.8) # 80-th percentile
# Out:
# Year                                               2016.000000
# Life Ladder                                           6.497157
# Log GDP per capita                                   10.375623
# Social support                                        0.913667
#                                                       ...
# Most people can be trusted, WVS round 1994-1998       0.304498
# Most people can be trusted, WVS round 1999-2004       0.388611
# Most people can be trusted, WVS round 2005-2009       0.415082
# Most people can be trusted, WVS round 2010-2014       0.373906
# Name: 0.8, Length: 25, dtype: float64

# %%
# Calling idxmax or idxmin on data will return the index of the row where

# The first minimum/maximum is found.

# However, it is only possible to call this on columns

# With some ordinality to them.

data.iloc[:,:-1].idxmax() # We exclude the Continent (last) Column
# Out:
# Year                                               Afghanistan
# Life Ladder                                            Denmark
# Log GDP per capita                                       Qatar
# Social support                                     New Zealand
#                                                       ...
# Most people can be trusted, WVS round 1994-1998         Norway
# Most people can be trusted, WVS round 1999-2004         Sweden
# Most people can be trusted, WVS round 2005-2009         Norway
# Most people can be trusted, WVS round 2010-2014    Netherlands
# Length: 25, dtype: object

# %%
# We can then say, Denmark has the highest Life Ladder.

# Qatar has the highest Log GDP per capita.

# New Zealand has the highest value for Social support.

# idxmin works the same as idxmax.

# %%
# Apply/Custom Functions:

# %%
# Two types of Custom Functions:

# Named Functions

# Lambda Functions

# %%
# Named Functions:

# FUNCTION:

def above_1000_below_10(x):
    try: # Test a block for errors
        pd.to_numeric(x) # Convert to numeric values
    except: # Handle the error.
        return 'no number column'
    
    if x > 1000:
        return 'above_1000'
    elif x < 10:
        return 'below_10'
    else:
        return 'mid'

# %%
data['Year'].apply(above_1000_below_10)
# Out:
# Country name
# Afghanistan    above_1000
# Afghanistan    above_1000
# Afghanistan    above_1000
# Afghanistan    above_1000
#                   ...
# Zimbabwe       above_1000
# Zimbabwe       above_1000
# Zimbabwe       above_1000
# Zimbabwe       above_1000
# Name: Year, Length: 1704, dtype: object

# %%
data['Year'].apply(above_1000_below_10)
# Out:
# Country name
# Afghanistan    above_1000
# Afghanistan    above_1000
# Afghanistan    above_1000
# Afghanistan    above_1000
#                   ...
# Zimbabwe       above_1000
# Zimbabwe       above_1000
# Zimbabwe       above_1000
# Zimbabwe       above_1000
# Name: Year, Length: 1704, dtype: object

# %%
# Defined a function called "above_1000_below_10"
# And applied that to our function.

# Function initially checks, if the value is convertible to a number
# And if not, will return "no number column".

# Otherwise, the function returns above_1000 if value is above 1000,
# And below_10 if the value is below 10.
# Else, it returns mid.

# %%
# Lambda Functions:

# Short, throw-away functions for one-time use only.
# The name sounds clunky, but once you got the hang of it, they are quite convenient.

# EXAMPLE:

# Could split the continent column on space and then grab the last word of the results.

data['Continent'].apply(lambda x: x.split(' ')[-1])
# Out:
# Country name
# Afghanistan      Asia
# Afghanistan      Asia
# Afghanistan      Asia
# Afghanistan      Asia
#                 ...
# Zimbabwe       Africa
# Zimbabwe       Africa
# Zimbabwe       Africa
# Zimbabwe       Africa
# Name: Continent, Length: 1704, dtype: object

# %%
# NOTE: Both, named and lambda functions, we applied to individual columns
# As opposed to the entire dataframe.

# When applying a function to a particular column, the function goes row by row.

# When applying a function to a whole DataFrame, the function goes column by column

# And is applied to the entire column, 

# Then and has to be written a little differently, like so:

def country_before_2015(df):
    if df['Year'] < 2015:
        return df.name
    else:
        return df['Continent']
    
# NOTE: the axis=1
data.apply(country_before_2015, axis =1)
# Out:
# Country name
# Afghanistan    Afghanistan
# Afghanistan    Afghanistan
# Afghanistan    Afghanistan
# Afghanistan    Afghanistan
#                   ...
# Zimbabwe            Africa
# Zimbabwe            Africa
# Zimbabwe            Africa
# Zimbabwe            Africa
# Length: 1704, dtype: object

# %%
# In this example, we also go row by row (as specified by the axis=1).

# Return the row (which happens to be the index)
# When the Year of that row is smaller than 2015 or else the continent
# Of that row.

# Tasks like this is for conditional data cleaning.

# %%
# Combining Columns:

# Sometimes you want to add, subtract or combine two or more columns.

data['Year'] + data['Life Ladder']
# Out:
# Country name
# Afghanistan    2011.723590
# Afghanistan    2013.401778
# Afghanistan    2014.758381
# Afghanistan    2014.831719
#                   ...
# Zimbabwe       2018.703191
# Zimbabwe       2019.735400
# Zimbabwe       2020.638300
# Zimbabwe       2021.616480
# Length: 1704, dtype: float64

# %%
data['Continent'] + '_' + data['Year'].astype(str)
# Out:
# Country name
# Afghanistan      Asia_2008
# Afghanistan      Asia_2009
# Afghanistan      Asia_2010
# Afghanistan      Asia_2011
#                   ...
# Zimbabwe       Africa_2015
# Zimbabwe       Africa_2016
# Zimbabwe       Africa_2017
# Zimbabwe       Africa_2018
# Length: 1704, dtype: object

# %%
# NOTE: In the example above, we want to combine two columns as strings.
# - To do this, we have to interpret data['Year'] as a string.
# - We do that by using .astype(str) on the column.
# - For the sake of brevity, we will not dive into types and type conversion.

# %%
# Groupby:

# So far, all the calculations we have applied were to the entire set,
# a row, or a column. However - and this is where it gets exciting -
# we can also group our data and calculate metrics for the individual groups.

# So, let's say we want to know the highest "Life Ladder" value per country.

# Looking for max of "Life Ladder" index, and we group the data by Country:
data.groupby(['Country name'])['Life Ladder'].max()
# Out:
# Country name
# Afghanistan    4.758381
# Albania        5.867422
# Algeria        6.354898
# Angola         5.589001
#                  ...
# Vietnam        5.767344
# Yemen          4.809259
# Zambia         5.260361
# Zimbabwe       4.955101
# Name: Life Ladder, Length: 165, dtype: float64

# %%
# Say, we want per year the country with the highest "Life Ladder".

data.groupby(['Year'])['Life Ladder'].idxmax()
# Out:
# Year
# 2005    Denmark
# 2006    Finland
# 2007    Denmark
# 2008    Denmark
#          ...
# 2015     Norway
# 2016    Finland
# 2017    Finland
# 2018    Finland
# Name: Life Ladder, Length: 14, dtype: object

# %%
# Or, multi-level groups, let's say we want per continent/year
# Combination the entry with the highest "Life Ladder."

# Let's say, we want per continent/per year combination 
# The entry with the highest "Life Ladder".

data.groupby(['Year', 'Continent'])['Life Ladder'].idxmax()
# Out:
# Year  Continent
# 2005  Africa                  Egypt
#       Asia             Saudi Arabia
#       Europe                Denmark
#       North America          Canada
#                            ...
# 2018  Europe                Finland
#       North America          Canada
#       Oceania           New Zealand
#       South America           Chile
# Name: Life Ladder, Length: 83, dtype: object

# %%
# Like before, we can use many standard functions or custom functions
# (named or unnamed) to, for example, return a random country per group:
import numpy as np

def get_random_country(group):
    return np.random.choice(group.index.values)

# %%
# Named function:

data.groupby(['Year', 'Continent']).apply(get_random_country)
# Out:
# Year  Continent
# 2005  Africa                   Egypt
#       Asia              Saudi Arabia
#       Europe                  Greece
#       North America           Mexico
#                            ...
# 2018  Europe            North Cyprus
#       North America    United States
#       Oceania              Australia
#       South America          Bolivia
# Length: 83, dtype: object

# %%
# NOTE: Groupby always returns ONE value per group.
# So, unless you are grouping by a column that only contains unique values,
# The result will be a smaller (an aggregated) dataset.

# %%
# transform

# Sometimes, you don't want only one value per group, but instead
# Want the value you calculated for the group for every row belonging
# To that group. You can do this the following way:

data.groupby(['Country name'])['Life Ladder'].transform(sum)
# Out:
# Country name
# Afghanistan    40.760446
# Afghanistan    40.760446
# Afghanistan    40.760446
# Afghanistan    40.760446
#                  ...
# Zimbabwe       52.387015
# Zimbabwe       52.387015
# Zimbabwe       52.387015
# Zimbabwe       52.387015
# Name: Life Ladder, Length: 1704, dtype: float64

# %%
# Here, we get the sum of all Life Ladder scores for a country.

# Can also do:

data.groupby(['Country name'])['Life Ladder'].transform(np.median)
# Out:
# Country name
# Afghanistan    3.782938
# Afghanistan    3.782938
# Afghanistan    3.782938
# Afghanistan    3.782938
#                  ...
# Zimbabwe       3.826268
# Zimbabwe       3.826268
# Zimbabwe       3.826268
# Zimbabwe       3.826268
# Name: Life Ladder, Length: 1704, dtype: float64

# %%
# Here, we obtained the median per country.
# We can then calculate the difference to the value
# Every single year like this (as transform preserves the index):

# %%
data.groupby(['Country name'])['Life Ladder'].transform(np.median)
- data['Life Ladder']
# Out:
# Country name
# Afghanistan   -3.723590
# Afghanistan   -4.401778
# Afghanistan   -4.758381
# Afghanistan   -3.831719
#                  ...
# Zimbabwe      -3.703191
# Zimbabwe      -3.735400
# Zimbabwe      -3.638300
# Zimbabwe      -3.616480
# Name: Life Ladder, Length: 1704, dtype: float64
